# %% [markdown]
# <a href="https://colab.research.google.com/github/241b065/aps-lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
import heapq

def dijkstra(graph, start):

    pq = [(0, start, [start])]
    distances = {node: float('inf') for node in graph}
    paths = {node: [] for node in graph}
    distances[start] = 0

    while pq:
        current_distance, current_node, path = heapq.heappop(pq)

        if current_distance > distances[current_node]:
            continue

        paths[current_node] = path

        for neighbor, weight in graph[current_node].items():
            distance = current_distance + weight
            if distance < distances[neighbor]:
                distances[neighbor] = distance
                heapq.heappush(pq, (distance, neighbor, path + [neighbor]))

    return distances, paths



graph = {
    'A': {'B': 2, 'C': 4},
    'B': {'A': 2, 'C': 1, 'D': 7},
    'C': {'A': 4, 'B': 1, 'E': 3},
    'D': {'B': 7, 'E': 2, 'F': 5},
    'E': {'C': 3, 'D': 2, 'F': 1},
    'F': {'D': 5, 'E': 1}
}

graph['G'] = {'E': 2, 'F': 3}
graph['H'] = {'C': 6, 'G': 4}

for source in ['A', 'C', 'H']:
    distances, paths = dijkstra(graph, source)
    print(f"\nSource Node: {source}")
    for node in graph:
        print(f"Shortest path to {node}: {paths[node]} with total distance {distances[node]}")
# Out:
# Source Node: A
# Shortest path to A: ['A'] with total distance 0
# Shortest path to B: ['A', 'B'] with total distance 2
# Shortest path to C: ['A', 'B', 'C'] with total distance 3
# Shortest path to D: ['A', 'B', 'C', 'E', 'D'] with total distance 8
# Shortest path to E: ['A', 'B', 'C', 'E'] with total distance 6
# Shortest path to F: ['A', 'B', 'C', 'E', 'F'] with total distance 7
# Shortest path to G: [] with total distance inf
# Shortest path to H: [] with total distance inf
#
# Source Node: C
# Shortest path to A: ['C', 'B', 'A'] with total distance 3
# Shortest path to B: ['C', 'B'] with total distance 1
# Shortest path to C: ['C'] with total distance 0
# Shortest path to D: ['C', 'E', 'D'] with total distance 5
# Shortest path to E: ['C', 'E'] with total distance 3
# Shortest path to F: ['C', 'E', 'F'] with total distance 4
# Shortest path to G: [] with total distance inf
# Shortest path to H: [] with total distance inf
#
# Source Node: H
# Shortest path to A: ['H', 'C', 'B', 'A'] with total distance 9
# Shortest path to B: ['H', 'C', 'B'] with total distance 7
# Shortest path to C: ['H', 'C'] with total distance 6
# Shortest path to D: ['H', 'G', 'E', 'D'] with total distance 8
# Shortest path to E: ['H', 'G', 'E'] with total distance 6
# Shortest path to F: ['H', 'G', 'F'] with total distance 7
# Shortest path to G: ['H', 'G'] with total distance 4
# Shortest path to H: ['H'] with total distance 0

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}
}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
